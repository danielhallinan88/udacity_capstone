# %%
from keras.layers import Conv1D, Conv2D, MaxPooling1D, MaxPooling2D, GlobalAveragePooling2D
from keras.layers import Dropout, Flatten, Dense, Activation, Reshape, Input, Embedding, LSTM, Concatenate
from keras.layers.normalization import BatchNormalization
from keras.models import Sequential, Model, load_model
from keras.utils  import to_categorical
from datetime     import datetime
import matplotlib.pyplot as plt
import numpy as np
import cv2
import os
# Out:
# Using TensorFlow backend.

# %%
data_dir = 'numpy_arrays'

X  = 'train_picture_features_cropped.npy'
y  = 'train_picture_labels.npy'

train_features = np.load(os.path.join(data_dir, X))
train_labels   = np.load(os.path.join(data_dir, y))

X  = 'test_picture_features_cropped.npy'
y  = 'test_picture_labels.npy'

test_features = np.load(os.path.join(data_dir, X))
test_labels   = np.load(os.path.join(data_dir, y))

print("Train feature shape:", train_features.shape)
print("Train label shape:", train_labels.shape)
print("Test feature shape:", test_features.shape)
print("Test label shape:", test_labels.shape)
# Out:
# Train feature shape: (33402,)
# Train label shape: (33402,)
# Test feature shape: (13068,)
# Test label shape: (13068,)

# %%
# %matplotlib inline

def display(feature_array, label_array, num):
    #print("LABEL: {}".format(label_array[num] ))
    fig,ax  = plt.subplots(1)
    ax.imshow(feature_array[num])
    fig.savefig('sample.png')

display(train_features, train_labels, -1)

# %%
# Preprocessing features
from skimage.transform import resize

def pad_features(features):
    new_features = []
    for feature in features:
        #print(feature.shape)
        height, width, _ = feature.shape
        if height > width:
            pad = np.zeros((int(height), int((height - width) / 2), 3))
            tmp = np.concatenate((pad, feature, pad), axis=1)
                
        else:
            pad = np.zeros((int((width - height) / 2), int(width), 3))
            tmp = np.concatenate((pad, feature, pad), axis=0)

        new_features.append(tmp)
    return np.array(new_features)

#################################

def resize_32x32(features):
    return np.array([resize(f, (32, 32, 3), mode='constant') for f in features])

def resize_32x32_grey(features):
    return np.array([resize(f, (32, 32, 1), mode='constant') for f in features])

def resize_64x64(features):
    return np.array([resize(f, (64, 64, 3), mode='constant') for f in features])

# %%
def preprocess_features(features):
    features = pad_features(features)
    features = resize_32x32(features)

    return features

# %%
# Preprocessing targets

def pad_labels(labels):

    max_len = 6
    
    for arr in labels:
        max_len = max(len(arr), max_len)
    
    return np.array([((max_len - len(arr)) * [10.0]) + arr for arr in labels])

def one_hot_encoding(labels):
    return np.array([ to_categorical(label, num_classes=11) for label in labels])

def remove_10s(labels):
    for label in labels:
        for i, digit in enumerate(label):
            if digit > 9:
                label[i] = 0.
                
    return labels

# %%
def preprocess_labels(labels):
    labels = remove_10s(labels)
    labels = pad_labels(labels)
    labels = one_hot_encoding(labels)
    labels = [labels[:, i] for i in range(6)]
    
    return labels

# %%
processed_train_features = preprocess_features(train_features)  
processed_train_labels   = preprocess_labels(train_labels)

processed_test_features  = preprocess_features(test_features)  
processed_test_labels    = preprocess_labels(test_labels)

print("Train feature shape:", processed_train_features.shape)
print("Train label shape: {} * {}".format(len(processed_train_labels), processed_train_labels[0].shape))
print("Test feature shape:", processed_test_features.shape)
print("Test label shape: {} * {}".format(len(processed_test_labels), processed_test_labels[0].shape))
# Out:
# Train feature shape: (33402, 32, 32, 3)
# Train label shape: 6 * (33402, 11)
# Test feature shape: (13068, 32, 32, 3)
# Test label shape: 6 * (13068, 11)

# %%
def decode_label(labels, num):
    return np.array([np.argmax(labels[digit_num][num]) for digit_num in range(len(labels))] )
    
display(processed_train_features, train_labels, -1)
decode_label(processed_train_labels, -1)
# Out:
# array([10, 10, 10,  1,  6,  9])

# %%
inputs_ = Input(shape=(32,32,3))
x = inputs_

x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = MaxPooling2D(pool_size=2)(x)
x = BatchNormalization()(x)
x = Dropout(0.25)(x)
x = Conv2D(96, (3, 3), activation='relu', padding='same')(x)
x = MaxPooling2D(pool_size=2)(x)
x = BatchNormalization()(x)
x = Dropout(0.25)(x)
x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = MaxPooling2D(pool_size=2)(x)
x = BatchNormalization()(x)
x = Dropout(0.25)(x)

###########################################
x = GlobalAveragePooling2D()(x)

x = Dense(512, activation='relu')(x)
x = Dense(512, activation='relu')(x)

digit1 = Dense(11, activation='softmax', name='digit1')(x)
digit2 = Dense(11, activation='softmax', name='digit2')(x)
digit3 = Dense(11, activation='softmax', name='digit3')(x)
digit4 = Dense(11, activation='softmax', name='digit4')(x)
digit5 = Dense(11, activation='softmax', name='digit5')(x)
digit6 = Dense(11, activation='softmax', name='digit6')(x)

model = Model(input=inputs_, outputs=[digit1, digit2, digit3, digit4, digit5, digit6])
model.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_1 (InputLayer)             (None, 32, 32, 3)     0
# ____________________________________________________________________________________________________
# conv2d_1 (Conv2D)                (None, 32, 32, 64)    1792
# ____________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)   (None, 16, 16, 64)    0
# ____________________________________________________________________________________________________
# batch_normalization_1 (BatchNorm (None, 16, 16, 64)    256
# ____________________________________________________________________________________________________
# dropout_1 (Dropout)              (None, 16, 16, 64)    0
# ____________________________________________________________________________________________________
# conv2d_2 (Conv2D)                (None, 16, 16, 96)    55392
# ____________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)   (None, 8, 8, 96)      0
# ____________________________________________________________________________________________________
# batch_normalization_2 (BatchNorm (None, 8, 8, 96)      384
# ____________________________________________________________________________________________________
# dropout_2 (Dropout)              (None, 8, 8, 96)      0
# ____________________________________________________________________________________________________
# conv2d_3 (Conv2D)                (None, 8, 8, 128)     110720
# ____________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)   (None, 4, 4, 128)     0
# ____________________________________________________________________________________________________
# batch_normalization_3 (BatchNorm (None, 4, 4, 128)     512
# ____________________________________________________________________________________________________
# dropout_3 (Dropout)              (None, 4, 4, 128)     0
# ____________________________________________________________________________________________________
# global_average_pooling2d_1 (Glob (None, 128)           0
# ____________________________________________________________________________________________________
# dense_1 (Dense)                  (None, 512)           66048
# ____________________________________________________________________________________________________
# dense_2 (Dense)                  (None, 512)           262656
# ____________________________________________________________________________________________________
# digit1 (Dense)                   (None, 11)            5643
# ____________________________________________________________________________________________________
# digit2 (Dense)                   (None, 11)            5643
# ____________________________________________________________________________________________________
# digit3 (Dense)                   (None, 11)            5643
# ____________________________________________________________________________________________________
# digit4 (Dense)                   (None, 11)            5643
# ____________________________________________________________________________________________________
# digit5 (Dense)                   (None, 11)            5643
# ____________________________________________________________________________________________________
# digit6 (Dense)                   (None, 11)            5643
# ====================================================================================================
# Total params: 531,618.0
# Trainable params: 531,042.0
# Non-trainable params: 576.0
# ____________________________________________________________________________________________________
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:30: UserWarning: Update your `Model` call to the Keras 2 API: `Model(outputs=[<tf.Tenso..., inputs=Tensor("in...)`

# %%
model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

from keras.callbacks import ModelCheckpoint

epochs     = 25
time_now   = datetime.now().strftime("%Y%m%d_%H%M%S")
model_path = os.path.join('models', 'multidigits' + str(epochs) + 'epochs_' + time_now +'.hdf5')

print("MODEL FILE: {}".format(model_path))

checkpointer = ModelCheckpoint(filepath=model_path, 
                               verbose=1, save_best_only=True, monitor='acc',)

model.fit(processed_train_features, 
          processed_train_labels,
          epochs=epochs, 
          batch_size=32, 
          callbacks=[checkpointer], 
          validation_data=(processed_test_features, processed_test_labels),
          verbose=1)
# Out:
# MODEL FILE: models/multidigits25epochs_20190716_191907.hdf5
# Train on 33402 samples, validate on 13068 samples
# Epoch 1/25
# 33402/33402 [==============================] - 266s - loss: 4.8208 - digit1_loss: 0.0046 - digit2_loss: 0.0071 - digit3_loss: 0.1473 - digit4_loss: 0.7958 - digit5_loss: 1.7917 - digit6_loss: 2.0742 - digit1_acc: 0.9990 - digit2_acc: 0.9988 - digit3_acc: 0.9578 - digit4_acc: 0.7584 - digit5_acc: 0.3792 - digit6_acc: 0.2470 - val_loss: 3.3771 - val_digit1_loss: 1.5959e-06 - val_digit2_loss: 0.0020 - val_digit3_loss: 0.0519 - val_digit4_loss: 0.3746 - val_digit5_loss: 1.2876 - val_digit6_loss: 1.6609 - val_digit1_acc: 1.0000 - val_digit2_acc: 0.9998 - val_digit3_acc: 0.9852 - val_digit4_acc: 0.8947 - val_digit5_acc: 0.5775 - val_digit6_acc: 0.4185
# /usr/local/lib/python3.5/dist-packages/keras/callbacks.py:388: RuntimeWarning: Can save best model only with acc available, skipping.
#   'skipping.' % (self.monitor), RuntimeWarning)
# Epoch 2/25
# 33402/33402 [==============================] - 267s - loss: 3.3975 - digit1_loss: 4.8336e-04 - digit2_loss: 0.0041 - digit3_loss: 0.1187 - digit4_loss: 0.5895 - digit5_loss: 1.2695 - digit6_loss: 1.4152 - digit1_acc: 1.0000 - digit2_acc: 0.9997 - digit3_acc: 0.9672 - digit4_acc: 0.8172 - digit5_acc: 0.5739 - digit6_acc: 0.5074 - val_loss: 2.3987 - val_digit1_loss: 1.2618e-07 - val_digit2_loss: 0.0024 - val_digit3_loss: 0.0413 - val_digit4_loss: 0.3095 - val_digit5_loss: 0.9376 - val_digit6_loss: 1.1079 - val_digit1_acc: 1.0000 - val_digit2_acc: 0.9998 - val_digit3_acc: 0.9871 - val_digit4_acc: 0.9061 - val_digit5_acc: 0.6903 - val_digit6_acc: 0.6282
# Epoch 3/25
# 33402/33402 [==============================] - 266s - loss: 2.7983 - digit1_loss: 4.8271e-04 - digit2_loss: 0.0048 - digit3_loss: 0.1073 - digit4_loss: 0.5292 - digit5_loss: 1.0592 - digit6_loss: 1.0973 - digit1_acc: 1.0000 - digit2_acc: 0.9997 - digit3_acc: 0.9713 - digit4_acc: 0.8333 - digit5_acc: 0.6439 - digit6_acc: 0.6201 - val_loss: 2.2783 - val_digit1_loss: 2.3063e-07 - val_digit2_loss: 0.0025 - val_digit3_loss: 0.0466 - val_digit4_loss: 0.4072 - val_digit5_loss: 0.8964 - val_digit6_loss: 0.9257 - val_digit1_acc: 1.0000 - val_digit2_acc: 0.9998 - val_digit3_acc: 0.9859 - val_digit4_acc: 0.8724 - val_digit5_acc: 0.7129 - val_digit6_acc: 0.6921
# Epoch 4/25
# 33402/33402 [==============================] - 266s - loss: 2.5055 - digit1_loss: 4.8268e-04 - digit2_loss: 0.0048 - digit3_loss: 0.1073 - digit4_loss: 0.4931 - digit5_loss: 0.9369 - digit6_loss: 0.9629 - digit1_acc: 1.0000 - digit2_acc: 0.9997 - digit3_acc: 0.9719 - digit4_acc: 0.8467 - digit5_acc: 0.6917 - digit6_acc: 0.6739 - val_loss: 2.0099 - val_digit1_loss: 1.7015e-07 - val_digit2_loss: 0.0025 - val_digit3_loss: 0.0800 - val_digit4_loss: 0.3688 - val_digit5_loss: 0.7763 - val_digit6_loss: 0.7823 - val_digit1_acc: 1.0000 - val_digit2_acc: 0.9998 - val_digit3_acc: 0.9714 - val_digit4_acc: 0.8766 - val_digit5_acc: 0.7606 - val_digit6_acc: 0.7476
# Epoch 5/25
# 33402/33402 [==============================] - 266s - loss: 2.3262 - digit1_loss: 4.8267e-04 - digit2_loss: 0.0048 - digit3_loss: 0.1018 - digit4_loss: 0.4745 - digit5_loss: 0.8617 - digit6_loss: 0.8830 - digit1_acc: 1.0000 - digit2_acc: 0.9997 - digit3_acc: 0.9747 - digit4_acc: 0.8526 - digit5_acc: 0.7156 - digit6_acc: 0.7012 - val_loss: 1.6849 - val_digit1_loss: 1.2980e-07 - val_digit2_loss: 0.0025 - val_digit3_loss: 0.0380 - val_digit4_loss: 0.2460 - val_digit5_loss: 0.6730 - val_digit6_loss: 0.7254 - val_digit1_acc: 1.0000 - val_digit2_acc: 0.9998 - val_digit3_acc: 0.9897 - val_digit4_acc: 0.9260 - val_digit5_acc: 0.7841 - val_digit6_acc: 0.7661
# Epoch 6/25
# 33402/33402 [==============================] - 266s - loss: 2.2034 - digit1_loss: 4.8267e-04 - digit2_loss: 0.0048 - digit3_loss: 0.0980 - digit4_loss: 0.4554 - digit5_loss: 0.8182 - digit6_loss: 0.8265 - digit1_acc: 1.0000 - digit2_acc: 0.9997 - digit3_acc: 0.9763 - digit4_acc: 0.8560 - digit5_acc: 0.7332 - digit6_acc: 0.7220 - val_loss: 1.9222 - val_digit1_loss: 1.2119e-07 - val_digit2_loss: 0.0025 - val_digit3_loss: 0.0359 - val_digit4_loss: 0.2651 - val_digit5_loss: 0.7993 - val_digit6_loss: 0.8194 - val_digit1_acc: 1.0000 - val_digit2_acc: 0.9998 - val_digit3_acc: 0.9907 - val_digit4_acc: 0.9237 - val_digit5_acc: 0.7495 - val_digit6_acc: 0.7349
# Epoch 7/25
# 33402/33402 [==============================] - 266s - loss: 2.1099 - digit1_loss: 4.8267e-04 - digit2_loss: 0.0048 - digit3_loss: 0.0995 - digit4_loss: 0.4491 - digit5_loss: 0.7753 - digit6_loss: 0.7807 - digit1_acc: 1.0000 - digit2_acc: 0.9997 - digit3_acc: 0.9757 - digit4_acc: 0.8610 - digit5_acc: 0.7476 - digit6_acc: 0.7397 - val_loss: 1.6422 - val_digit1_loss: 1.1945e-07 - val_digit2_loss: 0.0025 - val_digit3_loss: 0.0571 - val_digit4_loss: 0.2856 - val_digit5_loss: 0.6265 - val_digit6_loss: 0.6705 - val_digit1_acc: 1.0000 - val_digit2_acc: 0.9998 - val_digit3_acc: 0.9795 - val_digit4_acc: 0.9103 - val_digit5_acc: 0.8004 - val_digit6_acc: 0.7864
# Epoch 8/25
# 33402/33402 [==============================] - 267s - loss: 2.0493 - digit1_loss: 4.8267e-04 - digit2_loss: 0.0048 - digit3_loss: 0.0979 - digit4_loss: 0.4293 - digit5_loss: 0.7542 - digit6_loss: 0.7626 - digit1_acc: 1.0000 - digit2_acc: 0.9997 - digit3_acc: 0.9762 - digit4_acc: 0.8653 - digit5_acc: 0.7525 - digit6_acc: 0.7429 - val_loss: 1.6230 - val_digit1_loss: 1.1922e-07 - val_digit2_loss: 0.0025 - val_digit3_loss: 0.0368 - val_digit4_loss: 0.2802 - val_digit5_loss: 0.6508 - val_digit6_loss: 0.6528 - val_digit1_acc: 1.0000 - val_digit2_acc: 0.9998 - val_digit3_acc: 0.9908 - val_digit4_acc: 0.9119 - val_digit5_acc: 0.8015 - val_digit6_acc: 0.7945
# Epoch 9/25
# 33402/33402 [==============================] - 267s - loss: 2.0048 - digit1_loss: 4.8267e-04 - digit2_loss: 0.0048 - digit3_loss: 0.0948 - digit4_loss: 0.4269 - digit5_loss: 0.7378 - digit6_loss: 0.7400 - digit1_acc: 1.0000 - digit2_acc: 0.9997 - digit3_acc: 0.9774 - digit4_acc: 0.8672 - digit5_acc: 0.7612 - digit6_acc: 0.7555 - val_loss: 1.8082 - val_digit1_loss: 1.1921e-07 - val_digit2_loss: 0.0025 - val_digit3_loss: 0.0663 - val_digit4_loss: 0.3480 - val_digit5_loss: 0.7108 - val_digit6_loss: 0.6807 - val_digit1_acc: 1.0000 - val_digit2_acc: 0.9998 - val_digit3_acc: 0.9777 - val_digit4_acc: 0.8887 - val_digit5_acc: 0.7839 - val_digit6_acc: 0.7890
# Epoch 10/25
# 33402/33402 [==============================] - 267s - loss: 1.9799 - digit1_loss: 4.8267e-04 - digit2_loss: 0.0048 - digit3_loss: 0.0943 - digit4_loss: 0.4200 - digit5_loss: 0.7298 - digit6_loss: 0.7305 - digit1_acc: 1.0000 - digit2_acc: 0.9997 - digit3_acc: 0.9768 - digit4_acc: 0.8694 - digit5_acc: 0.7662 - digit6_acc: 0.7572 - val_loss: 1.6318 - val_digit1_loss: 1.1921e-07 - val_digit2_loss: 0.0025 - val_digit3_loss: 0.0453 - val_digit4_loss: 0.3079 - val_digit5_loss: 0.6439 - val_digit6_loss: 0.6323 - val_digit1_acc: 1.0000 - val_digit2_acc: 0.9998 - val_digit3_acc: 0.9858 - val_digit4_acc: 0.9002 - val_digit5_acc: 0.7978 - val_digit6_acc: 0.8014
# Epoch 11/25
# 33402/33402 [==============================] - 267s - loss: 1.9484 - digit1_loss: 4.8267e-04 - digit2_loss: 0.0048 - digit3_loss: 0.0938 - digit4_loss: 0.4157 - digit5_loss: 0.7198 - digit6_loss: 0.7139 - digit1_acc: 1.0000 - digit2_acc: 0.9997 - digit3_acc: 0.9780 - digit4_acc: 0.8732 - digit5_acc: 0.7685 - digit6_acc: 0.7617 - val_loss: 1.4645 - val_digit1_loss: 1.1921e-07 - val_digit2_loss: 0.0025 - val_digit3_loss: 0.0375 - val_digit4_loss: 0.2413 - val_digit5_loss: 0.5584 - val_digit6_loss: 0.6249 - val_digit1_acc: 1.0000 - val_digit2_acc: 0.9998 - val_digit3_acc: 0.9881 - val_digit4_acc: 0.9272 - val_digit5_acc: 0.8270 - val_digit6_acc: 0.8029
# Epoch 12/25
# 33402/33402 [==============================] - 267s - loss: 1.9137 - digit1_loss: 4.8267e-04 - digit2_loss: 0.0048 - digit3_loss: 0.0953 - digit4_loss: 0.4131 - digit5_loss: 0.7011 - digit6_loss: 0.6988 - digit1_acc: 1.0000 - digit2_acc: 0.9997 - digit3_acc: 0.9774 - digit4_acc: 0.8712 - digit5_acc: 0.7726 - digit6_acc: 0.7701 - val_loss: 1.4025 - val_digit1_loss: 1.1921e-07 - val_digit2_loss: 0.0025 - val_digit3_loss: 0.0495 - val_digit4_loss: 0.2478 - val_digit5_loss: 0.5423 - val_digit6_loss: 0.5604 - val_digit1_acc: 1.0000 - val_digit2_acc: 0.9998 - val_digit3_acc: 0.9839 - val_digit4_acc: 0.9258 - val_digit5_acc: 0.8369 - val_digit6_acc: 0.8227
# Epoch 13/25
# 33402/33402 [==============================] - 268s - loss: 1.9081 - digit1_loss: 4.8267e-04 - digit2_loss: 0.0048 - digit3_loss: 0.0938 - digit4_loss: 0.4124 - digit5_loss: 0.6945 - digit6_loss: 0.7020 - digit1_acc: 1.0000 - digit2_acc: 0.9997 - digit3_acc: 0.9784 - digit4_acc: 0.8714 - digit5_acc: 0.7776 - digit6_acc: 0.7714 - val_loss: 1.3735 - val_digit1_loss: 1.1921e-07 - val_digit2_loss: 0.0025 - val_digit3_loss: 0.0317 - val_digit4_loss: 0.2283 - val_digit5_loss: 0.5296 - val_digit6_loss: 0.5815 - val_digit1_acc: 1.0000 - val_digit2_acc: 0.9998 - val_digit3_acc: 0.9918 - val_digit4_acc: 0.9311 - val_digit5_acc: 0.8378 - val_digit6_acc: 0.8153
# Epoch 14/25
# 33402/33402 [==============================] - 267s - loss: 1.8717 - digit1_loss: 4.8267e-04 - digit2_loss: 0.0048 - digit3_loss: 0.0926 - digit4_loss: 0.4042 - digit5_loss: 0.6833 - digit6_loss: 0.6863 - digit1_acc: 1.0000 - digit2_acc: 0.9997 - digit3_acc: 0.9780 - digit4_acc: 0.8760 - digit5_acc: 0.7805 - digit6_acc: 0.7727 - val_loss: 2.3463 - val_digit1_loss: 1.1921e-07 - val_digit2_loss: 0.0025 - val_digit3_loss: 0.1253 - val_digit4_loss: 0.4925 - val_digit5_loss: 0.7814 - val_digit6_loss: 0.9447 - val_digit1_acc: 1.0000 - val_digit2_acc: 0.9998 - val_digit3_acc: 0.9536 - val_digit4_acc: 0.8440 - val_digit5_acc: 0.7707 - val_digit6_acc: 0.6917
# Epoch 15/25
# 33402/33402 [==============================] - 267s - loss: 1.8596 - digit1_loss: 4.8267e-04 - digit2_loss: 0.0048 - digit3_loss: 0.0930 - digit4_loss: 0.3986 - digit5_loss: 0.6847 - digit6_loss: 0.6779 - digit1_acc: 1.0000 - digit2_acc: 0.9997 - digit3_acc: 0.9787 - digit4_acc: 0.8775 - digit5_acc: 0.7807 - digit6_acc: 0.7791 - val_loss: 1.3975 - val_digit1_loss: 1.1921e-07 - val_digit2_loss: 0.0025 - val_digit3_loss: 0.0357 - val_digit4_loss: 0.2578 - val_digit5_loss: 0.5563 - val_digit6_loss: 0.5452 - val_digit1_acc: 1.0000 - val_digit2_acc: 0.9998 - val_digit3_acc: 0.9893 - val_digit4_acc: 0.9184 - val_digit5_acc: 0.8276 - val_digit6_acc: 0.8289
# Epoch 16/25
# 33402/33402 [==============================] - 267s - loss: 1.8548 - digit1_loss: 4.8267e-04 - digit2_loss: 0.0048 - digit3_loss: 0.0905 - digit4_loss: 0.4028 - digit5_loss: 0.6805 - digit6_loss: 0.6758 - digit1_acc: 1.0000 - digit2_acc: 0.9997 - digit3_acc: 0.9789 - digit4_acc: 0.8758 - digit5_acc: 0.7819 - digit6_acc: 0.7805 - val_loss: 1.6338 - val_digit1_loss: 1.1921e-07 - val_digit2_loss: 0.0025 - val_digit3_loss: 0.0711 - val_digit4_loss: 0.3278 - val_digit5_loss: 0.6107 - val_digit6_loss: 0.6217 - val_digit1_acc: 1.0000 - val_digit2_acc: 0.9998 - val_digit3_acc: 0.9781 - val_digit4_acc: 0.8992 - val_digit5_acc: 0.8108 - val_digit6_acc: 0.7946
# Epoch 17/25
# 33402/33402 [==============================] - 267s - loss: 1.8261 - digit1_loss: 4.8267e-04 - digit2_loss: 0.0048 - digit3_loss: 0.0905 - digit4_loss: 0.3882 - digit5_loss: 0.6709 - digit6_loss: 0.6711 - digit1_acc: 1.0000 - digit2_acc: 0.9997 - digit3_acc: 0.9787 - digit4_acc: 0.8784 - digit5_acc: 0.7853 - digit6_acc: 0.7779 - val_loss: 1.3382 - val_digit1_loss: 1.1921e-07 - val_digit2_loss: 0.0025 - val_digit3_loss: 0.0338 - val_digit4_loss: 0.2156 - val_digit5_loss: 0.5287 - val_digit6_loss: 0.5576 - val_digit1_acc: 1.0000 - val_digit2_acc: 0.9998 - val_digit3_acc: 0.9909 - val_digit4_acc: 0.9346 - val_digit5_acc: 0.8372 - val_digit6_acc: 0.8267
# Epoch 18/25
# 33402/33402 [==============================] - 266s - loss: 1.8189 - digit1_loss: 4.8267e-04 - digit2_loss: 0.0048 - digit3_loss: 0.0906 - digit4_loss: 0.3911 - digit5_loss: 0.6679 - digit6_loss: 0.6641 - digit1_acc: 1.0000 - digit2_acc: 0.9997 - digit3_acc: 0.9787 - digit4_acc: 0.8791 - digit5_acc: 0.7885 - digit6_acc: 0.7845 - val_loss: 1.7684 - val_digit1_loss: 1.1921e-07 - val_digit2_loss: 0.0025 - val_digit3_loss: 0.1092 - val_digit4_loss: 0.3295 - val_digit5_loss: 0.6837 - val_digit6_loss: 0.6436 - val_digit1_acc: 1.0000 - val_digit2_acc: 0.9998 - val_digit3_acc: 0.9622 - val_digit4_acc: 0.9015 - val_digit5_acc: 0.7829 - val_digit6_acc: 0.7925
# Epoch 19/25
# 33402/33402 [==============================] - 266s - loss: 1.8031 - digit1_loss: 4.8267e-04 - digit2_loss: 0.0048 - digit3_loss: 0.0913 - digit4_loss: 0.3916 - digit5_loss: 0.6566 - digit6_loss: 0.6581 - digit1_acc: 1.0000 - digit2_acc: 0.9997 - digit3_acc: 0.9780 - digit4_acc: 0.8797 - digit5_acc: 0.7899 - digit6_acc: 0.7854 - val_loss: 1.4452 - val_digit1_loss: 1.1921e-07 - val_digit2_loss: 0.0025 - val_digit3_loss: 0.0473 - val_digit4_loss: 0.2962 - val_digit5_loss: 0.5423 - val_digit6_loss: 0.5569 - val_digit1_acc: 1.0000 - val_digit2_acc: 0.9998 - val_digit3_acc: 0.9863 - val_digit4_acc: 0.9065 - val_digit5_acc: 0.8329 - val_digit6_acc: 0.8249
# Epoch 20/25
# 33402/33402 [==============================] - 267s - loss: 1.7665 - digit1_loss: 4.8267e-04 - digit2_loss: 0.0048 - digit3_loss: 0.0878 - digit4_loss: 0.3817 - digit5_loss: 0.6480 - digit6_loss: 0.6437 - digit1_acc: 1.0000 - digit2_acc: 0.9997 - digit3_acc: 0.9796 - digit4_acc: 0.8806 - digit5_acc: 0.7924 - digit6_acc: 0.7894 - val_loss: 1.5595 - val_digit1_loss: 1.1921e-07 - val_digit2_loss: 0.0025 - val_digit3_loss: 0.0319 - val_digit4_loss: 0.2253 - val_digit5_loss: 0.6029 - val_digit6_loss: 0.6969 - val_digit1_acc: 1.0000 - val_digit2_acc: 0.9998 - val_digit3_acc: 0.9909 - val_digit4_acc: 0.9323 - val_digit5_acc: 0.8031 - val_digit6_acc: 0.7737
# Epoch 21/25
# 33402/33402 [==============================] - 267s - loss: 1.7576 - digit1_loss: 4.8267e-04 - digit2_loss: 0.0048 - digit3_loss: 0.0870 - digit4_loss: 0.3752 - digit5_loss: 0.6452 - digit6_loss: 0.6449 - digit1_acc: 1.0000 - digit2_acc: 0.9997 - digit3_acc: 0.9803 - digit4_acc: 0.8847 - digit5_acc: 0.7908 - digit6_acc: 0.7905 - val_loss: 1.4085 - val_digit1_loss: 1.1921e-07 - val_digit2_loss: 0.0025 - val_digit3_loss: 0.0349 - val_digit4_loss: 0.2354 - val_digit5_loss: 0.5484 - val_digit6_loss: 0.5874 - val_digit1_acc: 1.0000 - val_digit2_acc: 0.9998 - val_digit3_acc: 0.9906 - val_digit4_acc: 0.9296 - val_digit5_acc: 0.8392 - val_digit6_acc: 0.8099
# Epoch 22/25
# 33402/33402 [==============================] - 267s - loss: 1.7489 - digit1_loss: 4.8267e-04 - digit2_loss: 0.0048 - digit3_loss: 0.0878 - digit4_loss: 0.3796 - digit5_loss: 0.6399 - digit6_loss: 0.6364 - digit1_acc: 1.0000 - digit2_acc: 0.9997 - digit3_acc: 0.9808 - digit4_acc: 0.8836 - digit5_acc: 0.7948 - digit6_acc: 0.7914 - val_loss: 1.3611 - val_digit1_loss: 1.1921e-07 - val_digit2_loss: 0.0025 - val_digit3_loss: 0.0333 - val_digit4_loss: 0.2349 - val_digit5_loss: 0.5559 - val_digit6_loss: 0.5345 - val_digit1_acc: 1.0000 - val_digit2_acc: 0.9998 - val_digit3_acc: 0.9910 - val_digit4_acc: 0.9296 - val_digit5_acc: 0.8351 - val_digit6_acc: 0.8298
# Epoch 23/25
# 33402/33402 [==============================] - 267s - loss: 1.7439 - digit1_loss: 4.8267e-04 - digit2_loss: 0.0048 - digit3_loss: 0.0865 - digit4_loss: 0.3764 - digit5_loss: 0.6407 - digit6_loss: 0.6350 - digit1_acc: 1.0000 - digit2_acc: 0.9997 - digit3_acc: 0.9797 - digit4_acc: 0.8832 - digit5_acc: 0.7964 - digit6_acc: 0.7936 - val_loss: 1.3071 - val_digit1_loss: 1.1921e-07 - val_digit2_loss: 0.0025 - val_digit3_loss: 0.0385 - val_digit4_loss: 0.2160 - val_digit5_loss: 0.5261 - val_digit6_loss: 0.5241 - val_digit1_acc: 1.0000 - val_digit2_acc: 0.9998 - val_digit3_acc: 0.9885 - val_digit4_acc: 0.9331 - val_digit5_acc: 0.8389 - val_digit6_acc: 0.8340
# Epoch 24/25
# 33402/33402 [==============================] - 267s - loss: 1.7232 - digit1_loss: 4.8267e-04 - digit2_loss: 0.0048 - digit3_loss: 0.0877 - digit4_loss: 0.3715 - digit5_loss: 0.6262 - digit6_loss: 0.6325 - digit1_acc: 1.0000 - digit2_acc: 0.9997 - digit3_acc: 0.9796 - digit4_acc: 0.8855 - digit5_acc: 0.7991 - digit6_acc: 0.7957 - val_loss: 1.2867 - val_digit1_loss: 1.1921e-07 - val_digit2_loss: 0.0025 - val_digit3_loss: 0.0286 - val_digit4_loss: 0.2271 - val_digit5_loss: 0.4907 - val_digit6_loss: 0.5379 - val_digit1_acc: 1.0000 - val_digit2_acc: 0.9998 - val_digit3_acc: 0.9936 - val_digit4_acc: 0.9321 - val_digit5_acc: 0.8535 - val_digit6_acc: 0.8290
# Epoch 25/25
# 33402/33402 [==============================] - 267s - loss: 1.7058 - digit1_loss: 4.8267e-04 - digit2_loss: 0.0048 - digit3_loss: 0.0885 - digit4_loss: 0.3681 - digit5_loss: 0.6198 - digit6_loss: 0.6242 - digit1_acc: 1.0000 - digit2_acc: 0.9997 - digit3_acc: 0.9798 - digit4_acc: 0.8859 - digit5_acc: 0.8006 - digit6_acc: 0.7964 - val_loss: 1.5357 - val_digit1_loss: 1.1921e-07 - val_digit2_loss: 0.0025 - val_digit3_loss: 0.0433 - val_digit4_loss: 0.3032 - val_digit5_loss: 0.5912 - val_digit6_loss: 0.5955 - val_digit1_acc: 1.0000 - val_digit2_acc: 0.9998 - val_digit3_acc: 0.9861 - val_digit4_acc: 0.9046 - val_digit5_acc: 0.8268 - val_digit6_acc: 0.8142

# %%
tmp = model.evaluate(processed_test_features, processed_test_labels, verbose=0)
loss, d1_loss, d2_loss, d3_loss, d4_loss, d5_loss, d6_loss, d1_acc, d2_acc, d3_acc, d4_acc, d5_acc, d6_acc = tmp

mean_loss = np.mean([d1_loss, d2_loss, d3_loss, d4_loss, d5_loss, d6_loss])
mean_acc  = np.mean([d1_acc, d2_acc, d3_acc, d4_acc, d5_acc, d6_acc])

print("LOSS: {}, ACCURACY: {}".format(mean_loss, mean_acc))
# Out:
# LOSS: 0.25594659207106224, ACCURACY: 0.9219084787236199

# %%
def predict(array):
    y_pred = model.predict(array)
    y_pred = np.array(y_pred)

    entries = [y_pred[:, i, :] for i in range(y_pred.shape[1])]

    all_digits = []
    for entry in entries:
        
        entry_digits = []
        for digit in entry:
            entry_digits.append(np.argmax(digit))

        all_digits.append(entry_digits)
   
    return np.array(all_digits).astype('float64')


samples     = 20
predictions = predict(processed_test_features[:samples])
for i, prediction in enumerate(predictions):
    p     = "".join([str(int(digit)) for digit in prediction if digit != 10.])
    label = "".join([str(int(digit)) for digit in test_labels[i]])
    print("Label: {}\tPrediction: {}".format(label, p))
# Out:
# Label: 5	Prediction: 5
# Label: 210	Prediction: 210
# Label: 6	Prediction: 6
# Label: 1	Prediction: 1
# Label: 9	Prediction: 9
# Label: 1	Prediction: 1
# Label: 183	Prediction: 183
# Label: 65	Prediction: 35
# Label: 144	Prediction: 184
# Label: 16	Prediction: 16
# Label: 34	Prediction: 34
# Label: 20	Prediction: 20
# Label: 13	Prediction: 19
# Label: 25	Prediction: 25
# Label: 4	Prediction: 14
# Label: 14	Prediction: 14
# Label: 28	Prediction: 20
# Label: 38	Prediction: 38
# Label: 60	Prediction: 60
# Label: 151	Prediction: 151

# %%
for i in range(samples):
    display(processed_test_features, processed_test_labels, i)

# %%
model.history.history.keys()
# Out:
# dict_keys(['digit1_loss', 'digit6_acc', 'val_digit3_acc', 'val_digit4_loss', 'val_digit5_loss', 'val_digit6_acc', 'val_digit2_acc', 'digit3_acc', 'val_digit1_acc', 'val_loss', 'val_digit6_loss', 'digit3_loss', 'digit4_loss', 'val_digit2_loss', 'loss', 'digit5_acc', 'digit4_acc', 'digit2_acc', 'val_digit3_loss', 'val_digit4_acc', 'digit5_loss', 'val_digit5_acc', 'digit6_loss', 'digit2_loss', 'digit1_acc', 'val_digit1_loss'])

# %%
accuracies = ['digit1_acc', 'digit2_acc', 'digit3_acc', 'digit4_acc', 'digit5_acc', 'digit6_acc']
for acc in accuracies:
    plt.plot(model.history.history[acc], label=acc.split('_')[0])

plt.title('Digit Learning Accuracy')
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.legend()
plt.show()
